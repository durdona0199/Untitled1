# %% [markdown]
# <a href="https://colab.research.google.com/github/durdona0199/Untitled1/blob/main/sabzavot_tannarxi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_error, r2_score

from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_excel("/content/ML uchun sabzavot 291025.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 14 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Unnamed: 0                                             19 non-null     int64
#  1   Махсулот тури                                          19 non-null     object
#  2   Меҳнат ҳақи  Жами харажатга нисбатан % да              19 non-null     float64
#  3   Минерал ўғитлар Жами харажатга нисбатан % да           19 non-null     float64
#  4   Кимёвий  Жами харажатга нисбатан % да                  19 non-null     float64
#  5   Уруғлик/кўчат Жами харажатга нисбатан % да             19 non-null     float64
#  6   ЁММ: Жами харажатга нисбатан % да                      19 non-null     float64
#  7   Механизация хизматлари Жами харажатга нисбатан % да    19 non-null     float64
# ...

# %%
le = LabelEncoder()
df['Махсулот тури'] = le.fit_transform(df['Махсулот тури'])

print("🔢 Kategoriyalar kodlash natijasi:")
print(pd.DataFrame({'product_type': le.classes_, 'kod': range(len(le.classes_))}))
# Out:
# 🔢 Kategoriyalar kodlash natijasi:
#          product_type  kod
# 0            айсберг     0
# 1     аччиқ қалампир     1
# 2           бақлажон     2
# 3            бодринг     3
# 4           броколли     4
# 5   булғор қалампири     5
# 6          гул карам     6
# 7              карам     7
# 8     картошка кечки     8
# 9         ош лавлаги     9
# 10          патиссон    10
# 11              пиёз    11
# 12       пиёз бахорги   12
# 13             полиз    13
# 14            помидор   14
# 15             сабзи    15
# 16             укроп    16
# 17            чеснок    17
# 18        шолғом/турп   18

# %%
df = df.rename(columns=lambda x: x.strip())  # boshidagi/oxiridagi bo‘sh joylarni olib tashlaydi

X = df[['Махсулот тури',
        'Меҳнат ҳақи  Жами харажатга нисбатан % да',
        'Минерал ўғитлар Жами харажатга нисбатан % да',
        'Кимёвий  Жами харажатга нисбатан % да',
        'Уруғлик/кўчат Жами харажатга нисбатан % да',
        'ЁММ: Жами харажатга нисбатан % да',
        'Механизация хизматлари Жами харажатга нисбатан % да',
        'Солиқлар Жами харажатга нисбатан % да',
        'Бошқа харажатлар Жами харажатга нисбатан % да',
        'Жами харажат',
        'Жами даромад',
        'Фойда']]

y = df['Рентабеллик даражаси %']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
model = Pipeline(steps=[
    ('scaler', StandardScaler()),
    ('regressor', RandomForestRegressor(
        n_estimators=100,
        random_state=42
    ))
])

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('regressor', RandomForestRegressor(random_state=42))])

# %%
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("✅ Model natijalari:")
print(f"MAE (o‘rtacha xato): {mae:.3f}")
print(f"R² (izohlangan dispersiya): {r2:.3f}")
# Out:
# ✅ Model natijalari:
# MAE (o‘rtacha xato): 20.741
# R² (izohlangan dispersiya): 0.061
